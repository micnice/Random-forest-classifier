# %%
import pandas as pd


df = pd.read_csv("Output.csv")

# %% [markdown]
# paracet, docs, coatemetha, erithromysing,amoxcline.

# %%
df
# Out:
#                                                     DEname  \
# 0        C1 12.1 Artesunate 200mg Suppositoire - jours ...
# 1        C1 12.1 Artesunate 400mg Suppositoire - stock ...
# 2        C1 12.1 Artesunate 400mg Suppositoire - quanti...
# 3        C1 12.1 Paracétamol 500mg Comprimé - quantité ...
# 4        C1 12.1 Gentamycine 80mg/2ml Injectable - stoc...
# 5        C1 12.1 Metronidazole 250mg Comprimé - stock d...
# 6        Artesunate+Amodiaquine, 50mg+135mg, Tab, 1-5an...
# 7        Quinine HCl/Sulf, 500mg base, Tab Zero or Posi...
# 8        Moustiquaire Impregnée d'insecticide Zero or P...
# 9        C1 12.1 Diazépam 5mg Injectable - quantité con...
# 10       C1 12.1 Amoxycilline 250mg Comprimé - jours ru...
# 11       Sulfadoxine + Pyrimethamine, 500+25mg, Tab Zer...
# 12       Artesunate+Amodiaquine, 25mg+67.5mg, Tab, 2-11...
# 13       C1 12.1 Ceftriaxone vial 1g Injectable - quant...
# 14       C2 12.2 Lidocaïne flacon 2% Injectable - Jours...
# ...

# %%
df.dtypes
# Out:
# DEname            object
# DEdescription     object
# DSname            object
# startdate         object
# enddate           object
# PeriodTypename    object
# value             object
# OUname            object
# coordinates       object
# dtype: object

# %%
df.drop(['DEdescription','enddate','PeriodTypename','coordinates'], axis=1)
# Out:
#                                                     DEname        DSname  \
# 0        C1 12.1 Artesunate 200mg Suppositoire - jours ...     C1- SIGL1
# 1        C1 12.1 Artesunate 400mg Suppositoire - stock ...     C1- SIGL1
# 2        C1 12.1 Artesunate 400mg Suppositoire - quanti...     C1- SIGL1
# 3        C1 12.1 Paracétamol 500mg Comprimé - quantité ...     C1- SIGL1
# 4        C1 12.1 Gentamycine 80mg/2ml Injectable - stoc...     C1- SIGL1
# 5        C1 12.1 Metronidazole 250mg Comprimé - stock d...     C1- SIGL1
# 6        Artesunate+Amodiaquine, 50mg+135mg, Tab, 1-5an...  C- SIGL FOSA
# 7        Quinine HCl/Sulf, 500mg base, Tab Zero or Posi...  C- SIGL FOSA
# 8        Moustiquaire Impregnée d'insecticide Zero or P...  C- SIGL FOSA
# 9        C1 12.1 Diazépam 5mg Injectable - quantité con...     C1- SIGL1
# 10       C1 12.1 Amoxycilline 250mg Comprimé - jours ru...     C1- SIGL1
# 11       Sulfadoxine + Pyrimethamine, 500+25mg, Tab Zer...  C- SIGL FOSA
# ...

# %%
# Out:
# (900722, 9)

# %%
df["Jan"] = newdf.value.where(newdf.startdate.values == '1/1/2019')

df["Feb"] = newdf.value.where(newdf.startdate.values == '2/1/2019')

df["March"] = newdf.value.where(newdf.startdate.values == '3/1/2019')
df["April"] = newdf.value.where(newdf.startdate.values == '4/1/2019')
df["May"] = newdf.value.where(newdf.startdate.values == '5/1/2019')
df["June"] = newdf.value.where(newdf.startdate.values == '6/1/2019')
df["July"] = newdf.value.where(newdf.startdate.values == '7/1/2019')
df["Aug"] = newdf.value.where(newdf.startdate.values == '8/1/2019')
df["Sept"] = newdf.value.where(newdf.startdate.values == '9/1/2019')
df["Oct"] = newdf.value.where(newdf.startdate.values == '10/1/2019')
df["Nov"] = newdf.value.where(newdf.startdate.values == '11/1/2019')
df["Dec"] = newdf.value.where(newdf.startdate.values == '12/1/2019')

# %%
df.DSname.unique()
# Out:
# array(['C1- SIGL1', 'C- SIGL FOSA', 'C2- SIGL2'], dtype=object)

# %%
newdf.Aug.unique()
# Out:
# array([nan, '26', '27', ..., 405.0, 812.0, 266.0], dtype=object)
