# %%
import pandas as pd

df = pd.read_csv("Output.csv")

# %% [markdown]
# paracet, docs, coatemetha, erithromysing,amoxcline.

# %%
df
# Out:
#                                                     DEname  \
# 0        C1 12.1 Artesunate 200mg Suppositoire - jours ...
# 1        C1 12.1 Artesunate 400mg Suppositoire - stock ...
# 2        C1 12.1 Artesunate 400mg Suppositoire - quanti...
# 3        C1 12.1 Paracétamol 500mg Comprimé - quantité ...
# 4        C1 12.1 Gentamycine 80mg/2ml Injectable - stoc...
# 5        C1 12.1 Metronidazole 250mg Comprimé - stock d...
# 6        Artesunate+Amodiaquine, 50mg+135mg, Tab, 1-5an...
# 7        Quinine HCl/Sulf, 500mg base, Tab Zero or Posi...
# 8        Moustiquaire Impregnée d'insecticide Zero or P...
# 9        C1 12.1 Diazépam 5mg Injectable - quantité con...
# 10       C1 12.1 Amoxycilline 250mg Comprimé - jours ru...
# 11       Sulfadoxine + Pyrimethamine, 500+25mg, Tab Zer...
# 12       Artesunate+Amodiaquine, 25mg+67.5mg, Tab, 2-11...
# 13       C1 12.1 Ceftriaxone vial 1g Injectable - quant...
# 14       C2 12.2 Lidocaïne flacon 2% Injectable - Jours...
# ...

# %%
df.DEname.unique()
# Out:
# array(['C1 12.1 Artesunate 200mg Suppositoire - jours rupture de stock',
#        'C1 12.1 Artesunate 400mg Suppositoire - stock disponible utilisable',
#        'C1 12.1 Artesunate 400mg Suppositoire - quantité perdue',
#        'C1 12.1 Paracétamol 500mg Comprimé - quantité perdue',
#        'C1 12.1 Gentamycine 80mg/2ml Injectable - stock disponible utilisable',
#        'C1 12.1 Metronidazole 250mg Comprimé - stock disponible utilisable',
#        'Artesunate+Amodiaquine, 50mg+135mg, Tab, 1-5ans Zero or Positive Int',
#        'Quinine HCl/Sulf, 500mg base, Tab Zero or Positive Int',
#        "Moustiquaire Impregnée d'insecticide Zero or Positive Int",
#        'C1 12.1 Diazépam 5mg Injectable - quantité consommée',
#        'C1 12.1 Amoxycilline 250mg Comprimé - jours rupture de stock',
#        'Sulfadoxine + Pyrimethamine, 500+25mg, Tab Zero or Positive Int',
#        'Artesunate+Amodiaquine, 25mg+67.5mg, Tab, 2-11mois Zero or Positive Int',
# ...

# %%
newdf = df[df["DSname"] == 'C- SIGL FOSA']
newdf.shape
# Out:
# (596129, 9)

# %%
newdf = newdf[newdf["DEname"] == 'Artemether+Luméfantrine, 20mg+120mg, 6Tab dispers., 2-11 mois Zero or Positive Int']
newdf.shape
# Out:
# (7138, 9)

# %%
sept = newdf[newdf["startdate"] == '9/1/2019']
sept.shape
# Out:
# (4241, 9)

# %%
aug = newdf[newdf["startdate"] == '8/1/2019']
aug.shape
# Out:
# (397, 9)

# %%
july = newdf[newdf["startdate"] == '7/1/2019']
july.shape
# Out:
# (363, 9)

# %%
july['value2']=aug.value
july.value2
# Out:
# /home/micnice/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# 136724     NaN
# 137255     NaN
# 137294     NaN
# 137296     NaN
# 137324     NaN
# 137399     NaN
# 137412     NaN
# 137486     NaN
# 241794     NaN
# 242244     NaN
# 242680     NaN
# 242681     NaN
# 242711     NaN
# 242756     NaN
# 242758     NaN
# 242806     NaN
# 283581     NaN
# 284113     NaN
# 284953     NaN
# 285001     NaN
# 285044     NaN
# 285080     NaN
# 328831     NaN
# 332273     NaN
# 332274     NaN
# 332374     NaN
# 332494     NaN
# 332495     NaN
# 332498     NaN
# 332522     NaN
#           ...
# 1369265    NaN
# 1389004    NaN
# 1389070    NaN
# ...

# %%
june = newdf[newdf["startdate"] == '6/1/2019']
june.shape
# Out:
# (628, 9)

# %%
may = newdf[newdf["startdate"] == '5/1/2019']
may.shape
# Out:
# (604, 9)

# %%
april = newdf[newdf["startdate"] == '4/1/2019']
april.shape
# Out:
# (547, 9)

# %%
march = newdf[newdf["startdate"] == '4/1/2019']
march.shape
# Out:
# (547, 9)

# %%
newdf2 = df[df["DSname"] == 'C1- SIGL1']
newdf2 = newdf2[newdf2["DEname"] == 'C1 12.1 Paracétamol 500mg Comprimé - quantité consommée']
sept = newdf2[newdf2["startdate"] == '9/1/2019']
sept.shape
# Out:
# (4310, 9)

# %%
aug = newdf2[newdf2["startdate"] == '8/1/2019']
aug
# Out:
#                                                   DEname DEdescription  \
# 2310     C1 12.1 Zinc 20mg Comprimé - quantité consommée           NaN
# 12342    C1 12.1 Zinc 20mg Comprimé - quantité consommée           NaN
# 18832    C1 12.1 Zinc 20mg Comprimé - quantité consommée           NaN
# 23381    C1 12.1 Zinc 20mg Comprimé - quantité consommée           NaN
# 30928    C1 12.1 Zinc 20mg Comprimé - quantité consommée           NaN
# 45633    C1 12.1 Zinc 20mg Comprimé - quantité consommée           NaN
# 55628    C1 12.1 Zinc 20mg Comprimé - quantité consommée           NaN
# 64907    C1 12.1 Zinc 20mg Comprimé - quantité consommée           NaN
# 64930    C1 12.1 Zinc 20mg Comprimé - quantité consommée           NaN
# 75728    C1 12.1 Zinc 20mg Comprimé - quantité consommée           NaN
# 80039    C1 12.1 Zinc 20mg Comprimé - quantité consommée           NaN
# 84140    C1 12.1 Zinc 20mg Comprimé - quantité consommée           NaN
# ...

# %%
july = newdf2[newdf2["startdate"] == '7/1/2019']
aug['value2']=july['value']
aug
# Out:
# /home/micnice/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                     DEname DEdescription  \
# 3214     C1 12.1 Paracétamol 500mg Comprimé - quantité ...           NaN
# 12321    C1 12.1 Paracétamol 500mg Comprimé - quantité ...           NaN
# 16632    C1 12.1 Paracétamol 500mg Comprimé - quantité ...           NaN
# 19443    C1 12.1 Paracétamol 500mg Comprimé - quantité ...           NaN
# 31408    C1 12.1 Paracétamol 500mg Comprimé - quantité ...           NaN
# 45801    C1 12.1 Paracétamol 500mg Comprimé - quantité ...           NaN
# 55862    C1 12.1 Paracétamol 500mg Comprimé - quantité ...           NaN
# ...

# %%
aug.shape
# Out:
# (155, 9)

# %%
july.shape
# Out:
# (51, 9)

# %%
sept.shape
# Out:
# (3651, 9)

# %%
# Splitting the dataset into the Training set and Test set

from sklearn.model_selection import train_test_split
X_Train, X_Test, Y_Train, Y_Test = train_test_split(X, Y, test_size = 0.25, random_state = 0)

# Feature Scaling

from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_Train = sc_X.fit_transform(X_Train)
X_Test = sc_X.transform(X_Test)

# Fitting the classifier into the Training set

from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 200, criterion = 'entropy', random_state = 0)
classifier.fit(X_Train,Y_Train)

# Predicting the test set results

Y_Pred = classifier.predict(X_Test)

# Making the Confusion Matrix 

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_Test, Y_Pred)

# Visualising the Training set results

from matplotlib.colors import ListedColormap
X_Set, Y_Set = X_Train, Y_Train
X1, X2 = np.meshgrid(np.arange(start = X_Set[:, 0].min() - 1, stop = X_Set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_Set[:, 1].min() - 1, stop = X_Set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())

# Visualising the Test set results

from matplotlib.colors import ListedColormap
X_Set, Y_Set = X_Test, Y_Test
X1, X2 = np.meshgrid(np.arange(start = X_Set[:, 0].min() - 1, stop = X_Set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_Set[:, 1].min() - 1, stop = X_Set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
